# %% [markdown]
# <a href="https://colab.research.google.com/github/anuhingankar9922-hub/-Python-Basic-Projects/blob/main/Optional_Task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("/Employee_Performance_Dataset.csv")

# %%
print(df.head())
# Out:
#    EmployeeID  Age Department  Experience  Salary  WorkHours  \
# 0        1001   29      Sales           8   78598         42
# 1        1002   30    Finance           8   74348         37
# 2        1003   24         IT           3   36140         42
# 3        1004   34         IT           5   57493         49
# 4        1005   22  Marketing           0   75753         45
#
#          Performance
# 0               Good
# 1  Needs Improvement
# 2          Excellent
# 3            Average
# 4            Average

# %%
print(df.tail())
# Out:
#     EmployeeID  Age Department  Experience  Salary  WorkHours  \
# 45        1046   54         IT          32   85793         37
# 46        1047   37    Finance          10   37856         42
# 47        1048   27    Finance           0   73081         45
# 48        1049   35      Sales           9   45642         47
# 49        1050   41         HR          13   50720         35
#
#           Performance
# 45          Excellent
# 46          Excellent
# 47            Average
# 48               Good
# 49  Needs Improvement

# %%
print(df.shape)
# Out:
# (50, 7)

# %%
print(df.columns)
# Out:
# Index(['EmployeeID', 'Age', 'Department', 'Experience', 'Salary', 'WorkHours',
#        'Performance'],
#       dtype='object')

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   EmployeeID   50 non-null     int64
#  1   Age          50 non-null     int64
#  2   Department   50 non-null     object
#  3   Experience   50 non-null     int64
#  4   Salary       50 non-null     int64
#  5   WorkHours    50 non-null     int64
#  6   Performance  50 non-null     object
# dtypes: int64(5), object(2)
# memory usage: 2.9+ KB
# None

# %%
print(df.dtypes)
# Out:
# EmployeeID      int64
# Age             int64
# Department     object
# Experience      int64
# Salary          int64
# WorkHours       int64
# Performance    object
# dtype: object

# %%
print(df.describe())
# Out:
#        EmployeeID        Age  Experience        Salary  WorkHours
# count    50.00000  50.000000   50.000000     50.000000  50.000000
# mean   1025.50000  38.280000   13.380000  62464.020000  42.240000
# std      14.57738   9.883071    9.824771  17470.468683   4.578388
# min    1001.00000  22.000000    0.000000  36140.000000  35.000000
# 25%    1013.25000  30.000000    5.000000  44796.250000  38.000000
# 50%    1025.50000  37.000000   11.000000  61060.000000  42.500000
# 75%    1037.75000  46.750000   21.000000  79112.500000  45.000000
# max    1050.00000  54.000000   32.000000  89337.000000  50.000000

# %%
print(df.isnull().sum())
# Out:
# EmployeeID     0
# Age            0
# Department     0
# Experience     0
# Salary         0
# WorkHours      0
# Performance    0
# dtype: int64

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
print(df.nunique())
# Out:
# EmployeeID     50
# Age            26
# Department      5
# Experience     28
# Salary         50
# WorkHours      16
# Performance     4
# dtype: int64

# %%
sns.countplot(x="Department", data=df)
plt.title("Department Distribution")
plt.show()

# %%
sns.countplot(x="Performance", data=df)
plt.title("Employee Performance")
plt.show()

# %%
plt.hist(df["Age"], bins=8)
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Count")
plt.show()

# %%
plt.hist(df["Salary"], bins=10)
plt.title("Salary Distribution")
plt.xlabel("Salary")
plt.ylabel("Employees")
plt.show()

# %%
plt.scatter(df["Experience"], df["Salary"])
plt.title("Experience vs Salary")
plt.xlabel("Experience")
plt.ylabel("Salary")
plt.show()

# %%
sns.boxplot(x="Department", y="Salary", data=df)
plt.title("Salary by Department")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="viridis")
plt.title("Correlation Heatmap")
plt.show()
